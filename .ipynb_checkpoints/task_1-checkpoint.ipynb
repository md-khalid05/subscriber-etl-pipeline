# %%
import sqlite3
import pandas as pd
import ast
import numpy as np
import os

# %%
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 import pyspark
#       2 from pyspark.sql import SparkSession
#       3 from pyspark.sql import functions as F
#
# ModuleNotFoundError: No module named 'pyspark'

# %%
spark = (
    SparkSession.builder
    .appName("SubscriberPipeline")
    .config("spark.sql.execution.arrow.pyspark.enabled", "true")
    .getOrCreate()
)

# %%
os.chdir("/Users/md_khalid/Data_Engineer/DataSet/codeacademy_dataset/subscriber-pipeline-starter-kit/dev")

# %%
con = sqlite3.connect('cademycode.db')
cur = con.cursor()

# %%
table_list = [a for a in cur.execute("SELECT name from sqlite_MASTER WHERE type = 'table'")]
print(table_list)
# Out:
# [('cademycode_students',), ('cademycode_courses',), ('cademycode_student_jobs',)]

# %%
students = pd.read_sql_query("SELECT * FROM cademycode_students", con)
career_path = pd.read_sql_query("SELECT * FROM cademycode_courses", con)
student_jobs = pd.read_sql_query("SELECT * FROM cademycode_student_jobs",con)

# %%
print('students:', len(students))
print('career_path:', len(career_path))
print('student_jobs:', len(student_jobs))
# Out:
# students: 5000
# career_path: 10
# student_jobs: 13

# %%
students.dtypes
# Out:
# uuid                       int64
# name                      object
# dob                       object
# sex                       object
# contact_info              object
# job_id                    object
# num_course_taken          object
# current_career_path_id    object
# time_spent_hrs            object
# dtype: object

# %%
schema_ddl = """
    uuid BIGINT,
    name STRING,
    dob STRING,
    sex STRING,
    contact_info STRING,
    job_id INT,
    num_course_taken INT,
    current_career_path_id INT,
    time_spent_hrs DOUBLE
"""

# Convert Pandas DF (from SQLite) to Spark DF
spark_students = spark.createDataFrame(students, schema=schema_ddl)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 14
#       1 schema_ddl = """
#       2     uuid BIGINT,
#       3     name STRING,
#    (...)     10     time_spent_hrs DOUBLE
#      11 """
#      13 # Convert Pandas DF (from SQLite) to Spark DF
# ---> 14 spark_students = spark.createDataFrame(students, schema=schema_ddl)
#
# NameError: name 'spark' is not defined

# %%
career_path.dtypes
# Out:
# career_path_id        int64
# career_path_name     object
# hours_to_complete     int64
# dtype: object

# %%
student_jobs.dtypes
# Out:
# job_id           int64
# job_category    object
# avg_salary       int64
# dtype: object
